# %%
import math
num1=16
num2=100
angle=30
print("square root",math.sqrt(num1))
print("factorial: ",math.factorial(num1))
print("log base 10: ",math.log10(num2))
print("value of pi: ",math.pi)
# Out:
# square root 4.0
# factorial:  20922789888000
# log base 10:  2.0
# value of pi:  3.141592653589793
