# %%
import pandas as pd

# Calling DataFrame constructor
df = pd.DataFrame()
print(df)

# list of strings
lst = ['ACE','ENG','CLG','CSE','ECE','CSD','IOT']

# Calling DataFrame constructor on list
df = pd.DataFrame(lst)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#      0
# 0  ACE
# 1  ENG
# 2  CLG
# 3  CSE
# 4  ECE
# 5  CSD
# 6  IOT
